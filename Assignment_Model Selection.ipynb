# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\aravi'

# %%
os.chdir('C:\\Users\\aravi\Downloads')

# %%
df = pd.read_csv('titanic_dataset .csv')

# %%
#loading dataset into python

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#to know the no of rows and cols
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Pre_processing

# %%
#to check the null values

df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#checking for duplicates

df.duplicated().sum()
# Out:
# 0

# %%
#to fill the null in AGE we use median method &ffill is used in embarkedb

df['Age'] = df['Age'].fillna(df['Age'].median())
df['Embarked'] = df['Embarked'].fillna(method = 'ffill')

# %%
df.drop('Cabin', axis = 1 , inplace = True)

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#changing the obj type using one hot encoding

df = pd.get_dummies(df, columns =['Sex','Embarked'])

# %%
#droping both name and ticket

df.drop(['Name','Ticket'], axis = 1, inplace =True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Age          891 non-null    float64
#  4   SibSp        891 non-null    int64
#  5   Parch        891 non-null    int64
#  6   Fare         891 non-null    float64
#  7   Sex_female   891 non-null    uint8
#  8   Sex_male     891 non-null    uint8
#  9   Embarked_C   891 non-null    uint8
#  10  Embarked_Q   891 non-null    uint8
#  11  Embarked_S   891 non-null    uint8
# dtypes: float64(2), int64(5), uint8(5)
# memory usage: 53.2 KB

# %%
df
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  \
# 0              1         0       3  22.0      1      0   7.2500           0
# 1              2         1       1  38.0      1      0  71.2833           1
# 2              3         1       3  26.0      0      0   7.9250           1
# 3              4         1       1  35.0      1      0  53.1000           1
# 4              5         0       3  35.0      0      0   8.0500           0
# ..           ...       ...     ...   ...    ...    ...      ...         ...
# 886          887         0       2  27.0      0      0  13.0000           0
# 887          888         1       1  19.0      0      0  30.0000           1
# 888          889         0       3  28.0      1      2  23.4500           1
# 889          890         1       1  26.0      0      0  30.0000           0
# 890          891         0       3  32.0      0      0   7.7500           0
#
#      Sex_male  Embarked_C  Embarked_Q  Embarked_S
# ...

# %%
#selecting the most probable columns fpor outlier detection

num_col = ['Fare','Age','SibSp','Pclass','Parch']

# %%
for i in num_col:
    plt.figure()
    plt.boxplot(df[i])
    plt.title(i)

# %%
# here the outliers are Fare ,Age ,SibSp ,Parch

# %%
#we are leaving both parch &sibsp as it is

# %%
#fare has large no of outliers so removing them

Q1 = np.percentile(df['Fare'],25,method = 'midpoint')
Q2 = np.percentile(df['Fare'],50,method = 'midpoint')
Q3 = np.percentile(df['Fare'],75,method = 'midpoint')

print("q1 is",Q1)
print("q2 is",Q2)
print("q3 is",Q3)

IQR = Q3-Q1
low_lim = Q1 - 1.5*IQR
up_lim = Q3 + 1.5*IQR

print('IQR is',IQR)
print('low_lim is',low_lim)
print('up_lim is',up_lim)
# Out:
# q1 is 7.9104
# q2 is 14.4542
# q3 is 31.0
# IQR is 23.0896
# low_lim is -26.724
# up_lim is 65.6344

# %%
#catching the outliers in fare and removing them
outlier = []
for x in df ["Fare"]:
    if((x>up_lim)or(x<low_lim)):
        outlier.append(x)

# %%
outlier
# Out:
# [71.2833,
#  263.0,
#  146.5208,
#  82.1708,
#  76.7292,
#  80.0,
#  83.475,
#  73.5,
#  263.0,
#  77.2875,
#  247.5208,
#  73.5,
#  77.2875,
#  79.2,
#  66.6,
#  69.55,
#  69.55,
#  146.5208,
#  69.55,
#  113.275,
#  76.2917,
#  90.0,
#  83.475,
#  90.0,
#  79.2,
#  86.5,
#  512.3292,
#  79.65,
#  153.4625,
#  135.6333,
#  77.9583,
#  78.85,
#  91.0792,
#  151.55,
#  247.5208,
#  151.55,
#  110.8833,
#  108.9,
#  83.1583,
#  262.375,
#  164.8667,
#  134.5,
#  69.55,
#  135.6333,
#  153.4625,
#  133.65,
#  66.6,
#  134.5,
#  263.0,
#  75.25,
#  69.3,
#  135.6333,
#  82.1708,
#  211.5,
#  227.525,
#  73.5,
#  120.0,
#  113.275,
#  90.0,
#  120.0,
#  263.0,
#  81.8583,
#  89.1042,
#  91.0792,
#  90.0,
#  78.2667,
#  151.55,
#  86.5,
#  108.9,
#  93.5,
#  221.7792,
#  106.425,
#  71.0,
#  106.425,
#  110.8833,
#  227.525,
#  79.65,
#  110.8833,
#  79.65,
#  79.2,
#  78.2667,
#  153.4625,
#  77.9583,
#  69.3,
#  76.7292,
#  73.5,
#  113.275,
#  133.65,
#  73.5,
#  512.3292,
#  76.7292,
# ...

# %%
removed = df["Fare"]>up_lim
df.loc[removed].index
df.drop(df.loc[removed].index,inplace = True)

# %%
print('skewness value of Age: ',df['Age'].skew())
# Out:
# skewness value of Age:  0.5182338915748297

# %%
# since the skewness value of age is less than 1 , they have almost to normal distribution

# %% [markdown]
# # Creating Training Model

# %%
x = df.drop('Survived' , axis=1)
y = df['Survived']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,recall_score,precision_score,classification_report,f1_score

# %%
metric_k=[]
neighbors=np.arange(3,20)
for k in neighbors:
    classifier=KNeighborsClassifier(n_neighbors=k,metric='euclidean')
    classifier.fit(x_train,y_train)
    y_pred_knn=classifier.predict(x_test)
    acc=accuracy_score(y_test,y_pred_knn)
    metric_k.append(acc)

# %%
metric_k
# Out:
# [0.5225806451612903,
#  0.567741935483871,
#  0.5612903225806452,
#  0.5806451612903226,
#  0.535483870967742,
#  0.5741935483870968,
#  0.5548387096774193,
#  0.5935483870967742,
#  0.5870967741935483,
#  0.6064516129032258,
#  0.6129032258064516,
#  0.6064516129032258,
#  0.6064516129032258,
#  0.6064516129032258,
#  0.6258064516129033,
#  0.6,
#  0.6064516129032258]

# %%
#plotting the graph to find the k value

plt.plot(neighbors,metric_k,'o-')
plt.xlabel('k')
plt.ylabel('accuracy')
plt.show()

# %%
#here lets take k as 17 as it gives the highest accuracy
knn=KNeighborsClassifier(n_neighbors=17)
knn.fit(x_train,y_train)
y_pred_knn=knn.predict(x_test)

# %%
print('Accuracy= ',accuracy_score(y_test,y_pred_knn))
# Out:
# Accuracy=  0.6258064516129033

# %%
confusion_matrix(y_test,y_pred_knn)
# Out:
# array([[91,  4],
#        [54,  6]], dtype=int64)

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
svm_cls=SVC(kernel='linear')
svm_cls=svm_cls.fit(x_train,y_train)
y_pred_svm1 = svm_cls.predict(x_test)

# %%
accuracy_score(y_test,y_pred_svm1)
# Out:
# 0.7548387096774194

# %%
confusion_matrix(y_test,y_pred_svm1)
# Out:
# array([[82, 13],
#        [25, 35]], dtype=int64)

# %% [markdown]
# # K-Fold Cross Validation

# %%
from sklearn.model_selection import KFold

# %%
k=KFold(10)

# %%
for train_index,test_index in k.split(x,y):
    print('Training Index: ',train_index)
    print('Testing Index: ',test_index)
# Out:
# Training Index:  [ 78  79  80  81  82  83  84  85  86  87  88  89  90  91  92  93  94  95
#   96  97  98  99 100 101 102 103 104 105 106 107 108 109 110 111 112 113
#  114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131
#  132 133 134 135 136 137 138 139 140 141 142 143 144 145 146 147 148 149
#  150 151 152 153 154 155 156 157 158 159 160 161 162 163 164 165 166 167
#  168 169 170 171 172 173 174 175 176 177 178 179 180 181 182 183 184 185
#  186 187 188 189 190 191 192 193 194 195 196 197 198 199 200 201 202 203
#  204 205 206 207 208 209 210 211 212 213 214 215 216 217 218 219 220 221
#  222 223 224 225 226 227 228 229 230 231 232 233 234 235 236 237 238 239
#  240 241 242 243 244 245 246 247 248 249 250 251 252 253 254 255 256 257
#  258 259 260 261 262 263 264 265 266 267 268 269 270 271 272 273 274 275
#  276 277 278 279 280 281 282 283 284 285 286 287 288 289 290 291 292 293
#  294 295 296 297 298 299 300 301 302 303 304 305 306 307 308 309 310 311
# ...

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_result_knn=cross_val_score(classifier,x,y,cv=k)

# %%
cv_result_knn
# Out:
# array([0.56410256, 0.78205128, 0.67948718, 0.58974359, 0.61538462,
#        0.38961039, 0.63636364, 0.7012987 , 0.68831169, 0.68831169])

# %%
np.mean(cv_result_knn)
# Out:
# 0.6334665334665335

# %%
cv_result_svm=cross_val_score(svm_cls,x,y,cv=k)

# %%
cv_result_svm
# Out:
# array([0.75641026, 0.83333333, 0.76923077, 0.79487179, 0.74358974,
#        0.81818182, 0.72727273, 0.74025974, 0.81818182, 0.77922078])

# %%
np.mean(cv_result_svm)
# Out:
# 0.7780552780552782

# %% [markdown]
# # Stratified K-Fold Cross Validation

# %%
from sklearn.model_selection import StratifiedKFold

sk=StratifiedKFold(n_splits=10)

# %%
for train_index,test_index in sk.split(x,y):
    print('Train Index: ',train_index)
    print('Testing Index: ',test_index)
# Out:
# Train Index:  [ 61  66  70  71  73  74  76  77  86  87  88  89  90  91  92  93  94  95
#   96  97  98  99 100 101 102 103 104 105 106 107 108 109 110 111 112 113
#  114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131
#  132 133 134 135 136 137 138 139 140 141 142 143 144 145 146 147 148 149
#  150 151 152 153 154 155 156 157 158 159 160 161 162 163 164 165 166 167
#  168 169 170 171 172 173 174 175 176 177 178 179 180 181 182 183 184 185
#  186 187 188 189 190 191 192 193 194 195 196 197 198 199 200 201 202 203
#  204 205 206 207 208 209 210 211 212 213 214 215 216 217 218 219 220 221
#  222 223 224 225 226 227 228 229 230 231 232 233 234 235 236 237 238 239
#  240 241 242 243 244 245 246 247 248 249 250 251 252 253 254 255 256 257
#  258 259 260 261 262 263 264 265 266 267 268 269 270 271 272 273 274 275
#  276 277 278 279 280 281 282 283 284 285 286 287 288 289 290 291 292 293
#  294 295 296 297 298 299 300 301 302 303 304 305 306 307 308 309 310 311
# ...

# %%
skcv_result_knn=cross_val_score( classifier,x,y,cv=sk)

skcv_result_knn
# Out:
# array([0.43589744, 0.66666667, 0.65384615, 0.64102564, 0.55128205,
#        0.62337662, 0.53246753, 0.62337662, 0.66233766, 0.66233766])

# %%
np.mean(skcv_result_knn)
# Out:
# 0.6052614052614051

# %%
skcv_result_svm=cross_val_score(svm_cls,x,y,cv=sk)

skcv_result_svm
# Out:
# array([0.80769231, 0.78205128, 0.75641026, 0.79487179, 0.79487179,
#        0.76623377, 0.76623377, 0.76623377, 0.79220779, 0.76623377])

# %%
np.mean(skcv_result_svm)
# Out:
# 0.7793040293040292
